# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename='logs/ingestion_db.log',
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a"
)

# %%
from sqlalchemy import create_engine

# Replace these with your actual MySQL credentials
username = "sk"
password = "123"
host = "localhost"  # or your server's IP
port = 3306  # default MySQL port
database = "inventory"

# MySQL connection string
engine = create_engine("mysql+pymysql://root:123@localhost:3306/inventory")

# %%
def ingest_db(df, table_name, engine):
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

# %%
def load_raw_data():
    start = time.time()
    chunk_size = 100_000  # Adjust based on available RAM

    for file in os.listdir('data'):
        if file.endswith('.csv'):
            file_path = os.path.join('data', file)
            print(f"Processing file: {file}")
            try:
                for chunk in pd.read_csv(file_path, chunksize=chunk_size):
                    print(f"Chunk shape: {chunk.shape}")
                    ingest_db(chunk, file[:-4], engine)  # Assuming this function is defined elsewhere
            except Exception as e:
                print(f"Error processing {file}: {e}")

    end = time.time()
    total_time = (end - start) / 60
    logging.info('------------Ingestion complete---------------')
    logging.info(f"\nTotal Time Taken : {total_time} minints")

if __name__ == "__main__":
  load_raw_data()
# Out:
# Processing file: begin_inventory.csv
# Chunk shape: (100000, 9)
# Chunk shape: (100000, 9)
# Chunk shape: (6529, 9)
# Processing file: end_inventory.csv
# Chunk shape: (100000, 9)
# Chunk shape: (100000, 9)
# Chunk shape: (24489, 9)
# Processing file: purchases.csv
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (100000, 16)
# Chunk shape: (72474, 16)
# Processing file: purchase_prices.csv
# ...
